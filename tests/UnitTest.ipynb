# %%
import sys
from pathlib import Path

repo_root = Path.cwd()
if not (repo_root / 'pcse_gym').exists():
    repo_root = repo_root.parent
sys.path.insert(0, str(repo_root))

import tests.initialize_env as init_env
import pcse_gym.utils.defaults as defaults

env = init_env.initialize_env(
    pcse_env=0,
    crop_features=defaults.get_default_crop_features(pcse_env=0),
    years=1992,
    locations=(52, 5.5),
)
obs, info = env.reset()
print('Environment reset OK, observation shape:', obs.shape)
